# %%
from pyspark.sql import SparkSession, DataFrame
import pyspark.sql.functions as F

DB_CONFIG = {
    'host': 'mysql-financial-db.c3imkkke2ssh.us-east-2.rds.amazonaws.com',
    'user': 'admin',
    'password': 'F(VD]Qe8r!BOCg72',
    'database': 'financial_db'
}

def create_spark_session() -> SparkSession:
    return (
        SparkSession
        .builder \
        .appName("MySQL to DataFrame") #type: ignore \
        .config ("hive.exec.dynamic.partition.mode", "nonstrict") \
        .config ("hive.exec.dynamic.partition", "true") \
        .config("spark.jars.packages", "mysql:mysql-connector-java:8.0.32") \
        .master("local[*]") \
        .getOrCreate()
    )

def read_mysql_table(spark: SparkSession, table_name: str, db_config: dict) -> DataFrame:
    return (
        spark
        .read
        .format ("jdbc")
        .option ("driver", "com.mysql.cj.jdbc.Driver")
        .option ("url", f"jdbc:mysql://{db_config['host']}/{db_config['database']}")
        .option ("user", db_config['user']) \
        .option ("password", db_config['password']) \
        .option ("dbtable", table_name) \
        .load()
    )

def main():
    spark = create_spark_session()
    df = read_mysql_table(spark, "contas", DB_CONFIG)
    df = df.withColumn("data_ingestao", F.current_timestamp())
    
    df.write.insertInto("`mariana_vetromille_database_sor`.`mariana_vetromille_table_contas`", overwrite=True)

if __name__ == "__main__":
    from traceback import format_exc
    try:
        main()
    except:
        print(format_exc())
        exit(1)
# Out:
# +---+--------------------+--------------------+--------------------+
# | id|                nome|           descricao|       data_ingestao|
# +---+--------------------+--------------------+--------------------+
# |  1|Credit Card - Ols...|Southern black vi...|2025-04-24 15:32:...|
# |  2|Checking - Hill, ...|Service happy aga...|2025-04-24 15:32:...|
# |  3|Cash - Morris, Ce...|Something evening...|2025-04-24 15:32:...|
# |  4|Savings - Meyer, ...|Difficult Mrs hug...|2025-04-24 15:32:...|
# |  5|Checking - Durham...|Manager anyone sh...|2025-04-24 15:32:...|
# |  6|Digital Wallet - ...|Since stock inste...|2025-04-24 15:32:...|
# |  7|Investment - Simm...|Pm administration...|2025-04-24 15:32:...|
# |  8|Retirement - Flor...|Kid different act...|2025-04-24 15:32:...|
# |  9|Savings - Hayes-B...|Pull hear member ...|2025-04-24 15:32:...|
# | 10|Checking - Taylor...|Tonight candidate...|2025-04-24 15:32:...|
# | 11|Credit Card - Flo...|So hit professor ...|2025-04-24 15:32:...|
# | 12|Retirement - John...|Bit stage himself...|2025-04-24 15:32:...|
# | 13|Retirement - Rice...|Image share feder...|2025-04-24 15:32:...|
# | 14|Credit Card - Web...|Can effect paper ...|2025-04-24 15:32:...|
# | 15|Checking - Carter...|Move north agreem...|2025-04-24 15:32:...|
# | 16|Cash - Scott, Wil...|Stock west health...|2025-04-24 15:32:...|
# | 17|Retirement - Brow...|After under measu...|2025-04-24 15:32:...|
# | 18|Cash - Buchanan-M...|Skin nature PM ch...|2025-04-24 15:32:...|
# | 19|    Cash - Ellis-Lee|And hear personal...|2025-04-24 15:32:...|
# | 20|Credit Card - Par...|Hair well fear re...|2025-04-24 15:32:...|
# +---+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# Traceback (most recent call last):
#   File "C:\Users\waltujo\AppData\Local\Temp\ipykernel_29960\931140634.py", line 48, in <module>
#     main()
#   File "C:\Users\waltujo\AppData\Local\Temp\ipykernel_29960\931140634.py", line 43, in main
#     df.write.insertInto("`mariana_vetromille_database_sor`.`mariana_vetromille_table_contas`", overwrite=True)
#     ^^
#   File "C:\Users\waltujo\AppData\Local\Temp\ipykernel_29960\931140634.py", line 43, in main
#     df.write.insertInto("`mariana_vetromille_database_sor`.`mariana_vetromille_table_contas`", overwrite=True)
#     ^^
#   File "_pydevd_bundle\\pydevd_cython.pyx", line 1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__
#   File "_pydevd_bundle\\pydevd_cython.pyx", line 634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle\\pydevd_cython.pyx", line 1368, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle\\pydevd_cython.pyx", line 1311, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle\\pydevd_cython.pyx", line 494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend
#   File "C:\Users\waltujo\AppData\Roaming\Python\Python311\site-packages\debugpy\_vendored\pydevd\pydevd.py", line 2188, in do_wait_suspend
#     keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\waltujo\AppData\Roaming\Python\Python311\site-packages\debugpy\_vendored\pydevd\pydevd.py", line 2257, in _do_wait_suspend
#     notify_event.wait(wait_timeout)
#   File "c:\Users\waltujo\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 622, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\waltujo\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\waltujo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\context.py", line 382, in signal_handler
#     raise KeyboardInterrupt()
# KeyboardInterrupt
